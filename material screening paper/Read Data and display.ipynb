# %% [markdown]
# ### Load Data
# The following notebook reads in the data from the 'data' folder and stores it in a PANDAS dataframe.

# %%
import pandas as pd

binary_sys = pd.read_pickle('data/binary_sys')
binary_sys['type'] = 'binary'
ternary_sys = pd.read_pickle('data/tern_data')
ternary_sys['type'] = 'ternary'

data = pd.concat([binary_sys,ternary_sys], ignore_index= True)

# %%
binary_sys.head()
# Out:
#     A  Ac_prop  Ag_prop  Al_prop  Ar_prop  As_prop  Au_prop   B  B_prop  \
# 0  Ac     0.05     0.95      NaN      NaN      NaN      NaN  Ag     NaN
# 1  Ac     0.10     0.90      NaN      NaN      NaN      NaN  Ag     NaN
# 2  Ac     0.15     0.85      NaN      NaN      NaN      NaN  Ag     NaN
# 3  Ac     0.20     0.80      NaN      NaN      NaN      NaN  Ag     NaN
# 4  Ac     0.25     0.75      NaN      NaN      NaN      NaN  Ag     NaN
#
#    Ba_prop   ...    formation_energy  max_en_diff  max_radius_diff  \
# 0      NaN   ...           -2.936805         0.83               35
# 1      NaN   ...           -3.041874         0.83               35
# 2      NaN   ...           -3.146944         0.83               35
# 3      NaN   ...           -3.252013         0.83               35
# 4      NaN   ...           -3.357083         0.83               35
#
#    max_z_diff  prop_d_elec  prop_f_elec  prop_p_elec  prop_s_elec  system  \
# ...

# %%
ternary_sys.head()
# Out:
#     A   B   C   Li_prop    N_prop   Zn_prop  avg_atomic_mass   avg_col  \
# 0  Li   N  Zn  0.333333  0.333333  0.333333        28.775899  9.333333
# 1  Bi  Ho  Pt       NaN       NaN       NaN       189.664663  8.333333
# 2  Bi  Gd  Pt       NaN       NaN       NaN       187.104665  8.333333
# 3  As  Li  Mg  0.333333       NaN       NaN        35.389200  6.000000
# 4  Pd  Sb  Sc       NaN       NaN       NaN        91.045300  9.333333
#
#    avg_d_elec    avg_en   ...     Tc_prop  Pu_prop  Np_prop  Ac_prop  Re_prop  \
# 0    3.333333  1.890000   ...         NaN      NaN      NaN      NaN      NaN
# 1    6.333333  1.843333   ...         NaN      NaN      NaN      NaN      NaN
# 2    6.666667  1.833333   ...         NaN      NaN      NaN      NaN      NaN
# 3    3.333333  1.490000   ...         NaN      NaN      NaN      NaN      NaN
# 4    7.000000  1.870000   ...         NaN      NaN      NaN      NaN      NaN
#
#    Xe_prop  Kr_prop  Pa_prop  Pm_prop     type
# ...

# %%
data.head()
# Out:
#     A  Ac_prop  Ag_prop  Al_prop  Ar_prop  As_prop  Au_prop   B  B_prop  \
# 0  Ac     0.05     0.95      NaN      NaN      NaN      NaN  Ag     NaN
# 1  Ac     0.10     0.90      NaN      NaN      NaN      NaN  Ag     NaN
# 2  Ac     0.15     0.85      NaN      NaN      NaN      NaN  Ag     NaN
# 3  Ac     0.20     0.80      NaN      NaN      NaN      NaN  Ag     NaN
# 4  Ac     0.25     0.75      NaN      NaN      NaN      NaN  Ag     NaN
#
#    Ba_prop   ...    index  max_en_diff  max_radius_diff max_z_diff  \
# 0      NaN   ...      NaN         0.83               35         42
# 1      NaN   ...      NaN         0.83               35         42
# 2      NaN   ...      NaN         0.83               35         42
# 3      NaN   ...      NaN         0.83               35         42
# 4      NaN   ...      NaN         0.83               35         42
#
#    prop_d_elec  prop_f_elec  prop_p_elec  prop_s_elec  system    type
# ...
